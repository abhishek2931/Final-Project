# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **ABHISHEK SHARMA**
#
# Data Scientist

# %% [markdown]
# *I am Interested in data science because i am in finance and accounts occupation from past 15 years and throughout my experience i have a passion for dealing with data. For example i get so excited when i have to deal with a lot of data and find resolutions even when using an excel file.*

# %% [markdown]
# ***My code will Add 1+1 and get results***

# %%
1+1
# Out:
# 2

# %% [markdown]
# *  Bulleted Item
#
# 1. Numbered Item
# 2.
#
# __(https://github.com/)__
